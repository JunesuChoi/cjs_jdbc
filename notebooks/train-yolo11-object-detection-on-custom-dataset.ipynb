# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train YOLO11 Object Detection on a Custom Dataset
#
# ---
#
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/ultralytics/ultralytics)
#
# YOLO11 builds on the advancements introduced in YOLOv9 and YOLOv10 earlier this year, incorporating improved architectural designs, enhanced feature extraction techniques, and optimized training methods.
#
# YOLO11m achieves a higher mean mAP score on the COCO dataset while using 22% fewer parameters than YOLOv8m, making it computationally lighter without sacrificing performance.
#
# YOLOv11 is available in 5 different sizes, ranging from `2.6M` to `56.9M` parameters, and capable of achieving from `39.5` to `54.7` mAP on the COCO dataset.

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Configure API keys
#
# To fine-tune YOLO11, you need to provide your Roboflow API key. Follow these steps:
#
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy`. This will place your private key in the clipboard.
# - In Colab, go to the left pane and click on `Secrets` (🔑). Store Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %% [markdown]
# ### Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Tue Sep 23 16:15:03 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLO11 via Ultralytics

# %%
# %pip install "ultralytics<=8.3.40" supervision roboflow
# prevent ultralytics from tracking your activity
# !yolo settings sync=False
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.40 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.3/112.6 GB disk)

# %% [markdown]
# ## Inference with model pre-trained on COCO dataset

# %% [markdown]
# ### CLI
#
# **NOTE:** CLI requires no customization or Python code. You can simply run all tasks from the terminal with the yolo command.

# %%
# !yolo task=detect mode=predict model=yolo11n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100% 5.35M/5.35M [00:00<00:00, 106MB/s]
# Ultralytics 8.3.40 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# Downloading https://media.roboflow.com/notebooks/examples/dog.jpeg to 'dog.jpeg'...
# 100% 104k/104k [00:00<00:00, 113MB/s]
# image 1/1 /content/dog.jpeg: 640x384 2 persons, 1 car, 1 dog, 1 handbag, 73.7ms
# Speed: 5.0ms preprocess, 73.7ms inference, 264.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **NOTE:** Result annotated image got saved in `{HOME}/runs/detect/predict/`. Let's display it.

# %%
# !ls {HOME}/runs/detect/predict/
# Out:
# dog.jpg

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/predict/dog.jpg', width=600)

# %% [markdown]
# ### SDK
#
# **NOTE:** YOLO's Python interface allows for seamless integration into your Python projects, making it easy to load, run, and process the model's output.

# %%
from ultralytics import YOLO
from PIL import Image
import requests

model = YOLO('yolo11n.pt')
image = Image.open(requests.get('https://media.roboflow.com/notebooks/examples/dog.jpeg', stream=True).raw)
result = model.predict(image, conf=0.25)[0]
# Out:
# 0: 640x384 2 persons, 1 car, 1 dog, 1 handbag, 104.4ms
# Speed: 5.5ms preprocess, 104.4ms inference, 140.6ms postprocess per image at shape (1, 3, 640, 384)

# %% [markdown]
# **NOTE:** The obtained `result` object stores information about the location, classes, and confidence levels of the detected objects.

# %%
result.boxes.xyxy
# Out:
# tensor([[3.0705e+02, 6.4341e+02, 5.2919e+02, 1.2558e+03],
#         [6.1400e+01, 2.4994e+02, 6.5165e+02, 9.7412e+02],
#         [1.7803e+00, 3.5551e+02, 6.3404e+02, 1.2788e+03],
#         [1.1933e+00, 3.5620e+02, 3.8455e+02, 1.2776e+03],
#         [6.2615e+02, 7.1818e+02, 6.9975e+02, 7.8754e+02]], device='cuda:0')

# %%
result.boxes.conf
# Out:
# tensor([0.6832, 0.6284, 0.5941, 0.3923, 0.3875], device='cuda:0')

# %%
result.boxes.cls
# Out:
# tensor([26., 16.,  0.,  0.,  2.], device='cuda:0')

# %% [markdown]
# **NOTE:** YOLO11 can be easily integrated with `supervision` using the familiar `from_ultralytics` connector.

# %%
import supervision as sv

detections = sv.Detections.from_ultralytics(result)

# %%
box_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator(text_color=sv.Color.BLACK)

annotated_image = image.copy()
annotated_image = box_annotator.annotate(annotated_image, detections=detections)
annotated_image = label_annotator.annotate(annotated_image, detections=detections)

sv.plot_image(annotated_image, size=(10, 10))

# %% [markdown]
# ## Fine-tune YOLO11 on custom dataset

# %% [markdown]
# **NOTE:** When training YOLOv11, make sure your data is located in `datasets`. If you'd like to change the default location of the data you want to use for fine-tuning, you can do so through Ultralytics' `settings.json`. In this tutorial, we will use one of the [datasets](https://universe.roboflow.com/liangdianzhong/-qvdww) available on [Roboflow Universe](https://universe.roboflow.com/). When downloading, make sure to select the `yolov11` export format.

# %%
# !pip install roboflow
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.12/dist-packages (1.2.9)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow) (2025.8.3)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.0.2)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (11.3.0)
# Requirement already satisfied: pi-heif<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.1.0)
# Requirement already satisfied: pillow-avif-plugin<2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (4.60.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (3.2.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->roboflow) (3.4.3)

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

from google.colab import userdata
from roboflow import Roboflow

ROBOFLOW_API_KEY = userdata.get('ROBOFLOW_API_KEY')
rf = Roboflow(api_key="be3pXSCfuc4NkQzPFxj3")

workspace = rf.workspace("plateworkout")
project = rf.workspace("plateworkout").project("owerlifting-plate-detector-9fixv")
version = project.version(9)
dataset = version.download("yolov11")
# Out:
# /content/datasets
# loading Roboflow workspace...
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in owerlifting-Plate-Detector-9 to yolov11:: 100%|██████████| 32384/32384 [00:00<00:00, 54546.95it/s]
# Extracting Dataset Version Zip to owerlifting-Plate-Detector-9 in yolov11:: 100%|██████████| 975/975 [00:00<00:00, 7255.08it/s]

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolo11n.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 plots=True
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.3.203 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolo11n.pt, data=/content/datasets/owerlifting-Plate-Detector-9/data.yaml, epochs=100, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758644588.938305    2768 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758644588.944245    2768 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1758644588.959645    2768 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758644588.959673    2768 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758644588.959679    2768 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758644588.959683    2768 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 319 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train2', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /content/datasets/owerlifting-Plate-Detector-9/train/labels.cache... 374 images, 2 backgrounds, 0 corrupt: 100% 374/374 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 242, len(boxes) = 3763. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# /usr/local/lib/python3.12/dist-packages/ultralytics/data/augment.py:1850: UserWarning: Argument(s) 'quality_lower' are not valid for transform ImageCompression
#   A.ImageCompression(quality_lower=75, p=0.0),
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/owerlifting-Plate-Detector-9/valid/labels.cache... 67 images, 0 backgrounds, 0 corrupt: 100% 67/67 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 5, len(boxes) = 601. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# Plotting labels to runs/detect/train2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.72G      1.493      2.663      1.268         99        640: 100% 24/24 [00:24<00:00,  1.04s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:05<00:00,  1.90s/it]
#                    all         67        601     0.0287       0.96      0.491      0.269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.64G      1.368      1.461      1.146        102        640: 100% 24/24 [00:07<00:00,  3.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.10it/s]
#                    all         67        601      0.751      0.225      0.381      0.202
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.51G      1.316      1.269      1.144         92        640: 100% 24/24 [00:05<00:00,  4.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.55it/s]
#                    all         67        601      0.698      0.582      0.683      0.386
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.71G      1.287      1.164      1.132         87        640: 100% 24/24 [00:06<00:00,  3.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.61it/s]
#                    all         67        601      0.749      0.719      0.768      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100       2.6G      1.256      1.115      1.112         97        640: 100% 24/24 [00:06<00:00,  3.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.30it/s]
#                    all         67        601      0.828      0.802      0.862      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.59G      1.251      1.063      1.114         83        640: 100% 24/24 [00:05<00:00,  4.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.87it/s]
#                    all         67        601      0.834      0.827      0.884       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.75G      1.197      1.013      1.093         70        640: 100% 24/24 [00:06<00:00,  3.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.62it/s]
#                    all         67        601      0.858      0.857      0.915      0.648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.64G      1.154     0.9633      1.064         87        640: 100% 24/24 [00:05<00:00,  4.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  5.56it/s]
#                    all         67        601      0.832        0.9      0.923      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100       2.6G        1.2     0.9737        1.1        150        640: 100% 24/24 [00:06<00:00,  3.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.99it/s]
#                    all         67        601       0.83       0.88       0.88      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.66G      1.129     0.9429      1.063         59        640: 100% 24/24 [00:06<00:00,  3.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.78it/s]
#                    all         67        601      0.874       0.85      0.923      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.61G      1.119     0.9316      1.065        111        640: 100% 24/24 [00:05<00:00,  4.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.40it/s]
#                    all         67        601      0.855      0.881       0.93      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.63G      1.149     0.9114      1.071         46        640: 100% 24/24 [00:06<00:00,  3.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.89it/s]
#                    all         67        601      0.873      0.861      0.929       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.54G      1.148     0.9049      1.064         92        640: 100% 24/24 [00:05<00:00,  4.24it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  5.42it/s]
#                    all         67        601      0.871      0.862      0.935       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.82G      1.111     0.8737      1.063         62        640: 100% 24/24 [00:06<00:00,  3.55it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.66it/s]
#                    all         67        601      0.836       0.91      0.932       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.48G      1.107     0.8567      1.051        121        640: 100% 24/24 [00:05<00:00,  4.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.14it/s]
#                    all         67        601      0.887       0.86      0.922       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.72G       1.06     0.8419      1.049        113        640: 100% 24/24 [00:05<00:00,  4.36it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4
0.755
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      2.62G     0.7292     0.4825     0.9214         79        640: 100% 24/24 [00:05<00:00,  4.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  6.08it/s]
#                    all         67        601      0.888      0.939      0.961      0.756
# Closing dataloader mosaic
# /usr/local/lib/python3.12/dist-packages/ultralytics/data/augment.py:1850: UserWarning: Argument(s) 'quality_lower' are not valid for transform ImageCompression
#   A.ImageCompression(quality_lower=75, p=0.0),
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      2.44G      0.718     0.4733      0.919         54        640: 100% 24/24 [00:08<00:00,  2.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.91it/s]
#                    all         67        601      0.881      0.935      0.958      0.747
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100       2.4G     0.7151     0.4631      0.922         79        640: 100% 24/24 [00:05<00:00,  4.37it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  5.90it/s]
#                    all         67        601       0.89      0.935      0.953      0.735
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      2.39G      0.712     0.4498      0.916         41        640: 100% 24/24 [00:06<00:00,  3.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  5.40it/s]
#                    all         67        601      0.905      0.931      0.956      0.735
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100       2.4G     0.7005     0.4422     0.9194         60        640: 100% 24/24 [00:05<00:00,  4.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.44it/s]
#                    all         67        601      0.895      0.936      0.955      0.734
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      2.39G     0.6978     0.4407     0.9158         53        640: 100% 24/24 [00:05<00:00,  4.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  5.79it/s]
#                    all         67        601      0.892       0.92      0.947      0.736
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      2.39G     0.7047     0.4426     0.9243         76        640: 100% 24/24 [00:06<00:00,  3.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  5.66it/s]
#                    all         67        601       0.89      0.932      0.948      0.732
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      2.37G     0.6835     0.4382     0.9096         48        640: 100% 24/24 [00:05<00:00,  4.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  5.00it/s]
#                    all         67        601      0.884      0.942       0.95      0.735
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      2.37G     0.6791     0.4326     0.9126         51        640: 100% 24/24 [00:06<00:00,  3.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  6.06it/s]
#                    all         67        601      0.881      0.948       0.95      0.736
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      2.37G     0.6772     0.4318     0.9127         53        640: 100% 24/24 [00:05<00:00,  4.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  4.97it/s]
#                    all         67        601      0.889      0.943      0.951      0.739
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100       2.4G      0.669     0.4226     0.9087         54        640: 100% 24/24 [00:06<00:00,  3.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:00<00:00,  3.64it/s]
#                    all         67        601      0.888      0.939      0.948      0.741
#
# 100 epochs completed in 0.223 hours.
# Optimizer stripped from runs/detect/train2/weights/last.pt, 5.5MB
# Optimizer stripped from runs/detect/train2/weights/best.pt, 5.5MB
#
# Validating runs/detect/train2/weights/best.pt...
# Ultralytics 8.3.40 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.23it/s]
#                    all         67        601      0.893      0.935      0.967      0.763
# Speed: 0.2ms preprocess, 4.3ms inference, 0.0ms loss, 2.5ms postprocess per image
# Results saved to runs/detect/train2
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# **NOTE:** The results of the completed training are saved in `{HOME}/runs/detect/train/`. Let's examine them.

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					    results.png
# confusion_matrix_normalized.png			    train_batch0.jpg
# confusion_matrix.png				    train_batch1.jpg
# events.out.tfevents.1758644331.c6f87528baf9.1601.0  train_batch2.jpg
# F1_curve.png					    val_batch0_labels.jpg
# labels_correlogram.jpg				    val_batch0_pred.jpg
# labels.jpg					    val_batch1_labels.jpg
# P_curve.png					    val_batch1_pred.jpg
# PR_curve.png					    val_batch2_labels.jpg
# R_curve.png					    val_batch2_pred.jpg
# results.csv					    weights

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/results.png', width=600)

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)

# %% [markdown]
# ## Validate fine-tuned model

# %%
# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.40 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /content/datasets/owerlifting-Plate-Detector-9/valid/labels.cache... 67 images, 0 backgrounds, 0 corrupt: 100% 67/67 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 5, len(boxes) = 601. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:02<00:00,  1.87it/s]
#                    all         67        601      0.886       0.89      0.948      0.711
# Speed: 4.3ms preprocess, 5.8ms inference, 0.0ms loss, 4.5ms postprocess per image
# Results saved to runs/detect/val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## Inference with custom model

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# Ultralytics 8.3.40 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 238 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/41 /content/datasets/owerlifting-Plate-Detector-9/test/images/20230425_154133_1_mp4-0004_jpg.rf.7a89faf7b68cb0f38ec70c4c5bab243e.jpg: 640x640 2 plates, 7.9ms
# image 2/41 /content/datasets/owerlifting-Plate-Detector-9/test/images/20230425_154133_1_mp4-0005_jpg.rf.c290004acfc2611c1fab3b6c3ea92a51.jpg: 640x640 5 plates, 8.0ms
# image 3/41 /content/datasets/owerlifting-Plate-Detector-9/test/images/20230425_154133_1_mp4-0006_jpg.rf.9ebede00edb26ad4d7a129b0213a3dc9.jpg: 640x640 3 plates, 7.9ms
# image 4/41 /content/datasets/owerlifting-Plate-Detector-9/test/images/20230425_154133_1_mp4-0024_jpg.rf.4f7e099459ce2f90034b4274f275d2b4.jpg: 640x640 6 plates, 7.9ms
# image 5/41 /content/datasets/owerlifting-Plate-Detector-9/test/images/20230425_154939_1_mp4-0001_jpg.rf.11a5b91438f34f85d2e34f80988338b6.jpg: 640x640 6 plates, 7.9ms
# image 6/41 /content/datasets/owerlifting-Plate-Detector-9/test/images/20230425_154939_1_mp4-0009_jpg.rf.5ea3bb99b50f6ff53788272fdc35c976.jpg: 640x640 5 plates, 7.9ms
# image 7/41 /content/datasets/owerlifting-Plate-Detector-9/test/images/20230425_154939_1_mp4-0010_jpg.rf.19d0963729704e480e2a2a78aa611b00.jpg: 640x640 5 plates, 7.9ms
# image 8/41 /content/datasets/owerlifting-Plate-Detector-9/test/images/20230425
41 /content/datasets/owerlifting-Plate-Detector-9/test/images/20230821_133318_1_mp4-0005_jpg.rf.c9d40940890d1eaee2d45f20fdddc7ad.jpg: 640x640 17 plates, 7.0ms
# image 32/41 /content/datasets/owerlifting-Plate-Detector-9/test/images/Frame-000022_png.rf.4efaa350d1a2b3d00eca6d9f93b762bf.jpg: 640x640 3 plates, 6.8ms
# image 33/41 /content/datasets/owerlifting-Plate-Detector-9/test/images/Frame-000024_png.rf.a8f4902ad4b54efe9b8d190baded3882.jpg: 640x640 3 plates, 7.1ms
# image 34/41 /content/datasets/owerlifting-Plate-Detector-9/test/images/Frame-000036_png.rf.f3bacce8714d76aecd25ad3141f95d0f.jpg: 640x640 2 plates, 6.8ms
# image 35/41 /content/datasets/owerlifting-Plate-Detector-9/test/images/Frame-000065_png.rf.9f2c5a1654934b76b5d917f03f2a754f.jpg: 640x640 2 plates, 7.0ms
# image 36/41 /content/datasets/owerlifting-Plate-Detector-9/test/images/Frame-007660_png.rf.2a2d713e08cb4bd9c35dc77d5de73440.jpg: 640x640 2 plates, 6.9ms
# image 37/41 /content/datasets/owerlifting-Plate-Detector-9/test/images/Frame-007667_png.rf.b96853454435dbc68f13d32f76cbf894.jpg: 640x640 2 plates, 7.7ms
# image 38/41 /content/datasets/owerlifting-Plate-Detector-9/test/images/Frame-007674_png.rf.2578f243735a04766773ed9f4cf170d6.jpg: 640x640 2 plates, 7.0ms
# image 39/41 /content/datasets/owerlifting-Plate-Detector-9/test/images/Frame-007761_png.rf.0f5213a9da366dfb7ef3e098ac48acad.jpg: 640x640 1 plate, 7.3ms
# image 40/41 /content/datasets/owerlifting-Plate-Detector-9/test/images/Frame-007787_png.rf.bb6f359a7b51eb84c6f282e89a9ffc48.jpg: 640x640 2 plates, 6.8ms
# image 41/41 /content/datasets/owerlifting-Plate-Detector-9/test/images/Frame-007806_png.rf.1ec0b4dd2b5b851dd4b111bdf0de4201.jpg: 640x640 3 plates, 7.0ms
# Speed: 1.4ms preprocess, 7.4ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob(f'{HOME}/runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[:3]:
    display(IPyImage(filename=img, width=600))
    print("\n")

# %%
# %pip install sng4onnx>=1.0.1 onnx_graphsurgeon>=0.3.26 onnx>=1.12.0 "onnx2tf>1.17.5,<=1.22.3" onnxslim>=0.1.31 tflite_support onnxruntime tensorflow

# %%
# !pip install --upgrade ultralytics onnx onnx2tf
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.12/dist-packages (8.3.40)
# Collecting ultralytics
#   Downloading ultralytics-8.3.203-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: onnx in /usr/local/lib/python3.12/dist-packages (1.19.0)
# Requirement already satisfied: onnx2tf in /usr/local/lib/python3.12/dist-packages (1.22.3)
# Collecting onnx2tf
#   Downloading onnx2tf-1.28.2-py3-none-any.whl.metadata (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.2/151.2 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.23.0+cu126)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.25.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.17)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (5.29.5)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (4.15.0)
# Requirement already satisfied: ml_dtypes in /usr/local/lib/python3.12/dist-packages (from onnx) (0.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.203-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 32.5 MB/s eta 0:00:00
# Downloading onnx2tf-1.28.2-py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.3/468.3 kB 42.6 MB/s eta 0:00:00
# Installing collected packages: onnx2tf, ultralytics
#   Attempting uninstall: onnx2tf
#     Found existing installation: onnx2tf 1.22.3
#     Uninstalling onnx2tf-1.22.3:
#       Successfully uninstalled onnx2tf-1.22.3
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.3.40
#     Uninstalling ultralytics-8.3.40:
#       Successfully uninstalled ultralytics-8.3.40
# Successfully installed onnx2tf-1.28.2 ultralytics-8.3.203

# %%
# HOME 변수와 best.pt 파일 경로 설정
import os
HOME = os.getcwd()
model_path = f"{HOME}/runs/detect/train/weights/best.pt" # 본인의 best.pt 경로에 맞게 수정하세요.

# ONNX 형식으로만 export 합니다.
# !yolo export model={model_path} format=onnx
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CPU (Intel Xeon 2.20GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '/content/runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.19.0 opset 22...
# ONNX: slimming with onnxslim 0.1.69...
# ONNX: export success ✅ 1.5s, saved as '/content/runs/detect/train/weights/best.onnx' (10.1 MB)
#
# Export complete (2.0s)
# Results saved to /content/runs/detect/train/weights
# Predict:         yolo predict task=detect model=/content/runs/detect/train/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=/content/runs/detect/train/weights/best.onnx imgsz=640 data=/content/datasets/owerlifting-Plate-Detector-9/data.yaml
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export

# %%
# !pip install ai-edge-litert
# Out:
# Collecting ai-edge-litert
#   Downloading ai_edge_litert-2.0.2-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (1.9 kB)
# Collecting backports.strenum (from ai-edge-litert)
#   Downloading backports_strenum-1.2.8-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert) (25.2.10)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert) (4.15.0)
# Downloading ai_edge_litert-2.0.2-cp312-cp312-manylinux_2_27_x86_64.whl (91.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 MB 9.8 MB/s eta 0:00:00
# Downloading backports_strenum-1.2.8-py3-none-any.whl (7.9 kB)
# Installing collected packages: backports.strenum, ai-edge-litert
# Successfully installed ai-edge-litert-2.0.2 backports.strenum-1.2.8

# %%
# .pt 파일 경로에서 .onnx 파일 경로 생성
onnx_path = model_path.replace('.pt', '.onnx')

# onnx2tf 명령어를 사용하여 TFLite로 변환 (INT8 양자화 포함)
# !onnx2tf -i {onnx_path} -o tflite_model -otfl -oi8
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758647632.117113   15921 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758647632.123339   15921 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1758647632.139369   15921 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758647632.139398   15921 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758647632.139402   15921 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1758647632.139407   15921 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
#
# Model optimizing started ============================================================
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/onnx2tf/onnx2tf.py", line 684, in convert
#     result = subprocess.check_output(
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 466, in check_output
#     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "/usr/lib/python3.12/subprocess.py", line 1955, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# FileNotFoundError: [Errno 2] No such file or directory: 'onnxsim'
#
# WARNING: Failed to optimize the onnx file.
#
# Automatic generation of each OP name started ========================================
# Automatic generation of each OP name complete!
#
# Model loaded ========================================================================
#
# Model conversion started ============================================================
# INFO: input_op_name: images shape: [1, 3, 640, 640] dtype: float32
#
# INFO: 2 / 321
# INFO: onnx_op_type: Conv onnx_op_name: /model.0/conv/Conv
# INFO:  input_name.1: images shape: [1, 3, 640, 640] dtype: float32
# INFO:  input_name.2: model.0.conv.weight shape: [16, 3, 3, 3] dtype: float32
# INFO:  input_name.3: model.0.conv.bias shape: [16] dtype: float32
# INFO:  output_name.1: /model.0/conv/Conv_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.pad/Pad:0 shape: (1, 642, 642, 3) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 3, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add/Add:0 shape: (1, 320, 320, 16) dtype: <dtype: 'float32'>
#
# INFO: 3 / 321
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.0/act/Sigmoid
# INFO:  input_name.1: /model.0/conv/Conv_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO:  output_name.1: /model.0/act/Sigmoid_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add/Add:0 shape: (1, 320, 320, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid/Sigmoid:0 shape: (1, 320, 320, 16) dtype: <dtype: 'float32'>
#
# INFO: 4 / 321
# INFO: onnx_op_type: Mul onnx_op_name: /model.0/act/Mul
# INFO:  input_name.1: /model.0/conv/Conv_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO:  input_name.2: /model.0/act/Sigmoid_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO:  output_name.1: /model.0/act/Mul_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add/Add:0 shape: (1, 320, 320, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid/Sigmoid:0 shape: (1, 320, 320, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_3/Mul:0 shape: (1, 320, 320, 16) dtype: <dtype: 'float32'>
#
# INFO: 5 / 321
# INFO: onnx_op_type: Conv onnx_op_name: /model.1/conv/Conv
# INFO:  input_name.1: /model.0/act/Mul_output_0 shape: [1, 16, 320, 320] dtype: float32
# INFO:  input_name.2: model.1.conv.weight shape: [32, 16, 3, 3] dtype: float32
# INFO:  input_name.3: model.1.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: /model.1/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.pad_1/Pad:0 shape: (1, 322, 322, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 16, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_1/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 6 / 321
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.1/act/Sigmoid
# INFO:  input_name.1: /model.1/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  output_name.1: /model.1/act/Sigmoid_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_1/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_1/Sigmoid:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 7 / 321
# INFO: onnx_op_type: Mul onnx_op_name: /model.1/act/Mul
# INFO:  input_name.1: /model.1/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  input_name.2: /model.1/act/Sigmoid_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  output_name.1: /model.1/act/Mul_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_1/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_1/Sigmoid:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_7/Mul:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 8 / 321
# INFO: onnx_op_type: Conv onnx_op_name: /model.2/cv1/conv/Conv
# INFO:  input_name.1: /model.1/act/Mul_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  input_name.2: model.2.cv1.conv.weight shape: [32, 32, 1, 1] dtype: float32
# INFO:  input_name.3: model.2.cv1.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: /model.2/cv1/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_7/Mul:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_2/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 9 / 321
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.2/cv1/act/Sigmoid
# INFO:  input_name.1: /model.2/cv1/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  output_name.1: /model.2/cv1/act/Sigmoid_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_2/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_2/Sigmoid:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 10 / 321
# INFO: onnx_op_type: Mul onnx_op_name: /model.2/cv1/act/Mul
# INFO:  input_name.1: /model.2/cv1/conv/Conv_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  input_name.2: /model.2/cv1/act/Sigmoid_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  output_name.1: /model.2/cv1/act/Mul_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_2/Add:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_2/Sigmoid:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_11/Mul:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
#
# INFO: 11 / 321
# INFO: onnx_op_type: Split onnx_op_name: /model.2/Split
# INFO:  input_name.1: /model.2/cv1/act/Mul_output_0 shape: [1, 32, 160, 160] dtype: float32
# INFO:  input_name.2: onnx::Split_185 shape: [2] dtype: int64
# INFO:  output_name.1: /model.2/Split_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.2: /model.2/Split_output_1 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: split
# INFO:  input.1.value: name: tf.math.multiply_11/Mul:0 shape: (1, 160, 160, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.num_or_size_splits: shape: (2,) dtype: int64
# INFO:  input.3.axis: val: 3
# INFO:  input.4.num:
# INFO:  output.1.output0: name: tf.strided_slice/StridedSlice:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  output.2.output1: name: tf.strided_slice_1/StridedSlice:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 12 / 321
# INFO: onnx_op_type: Conv onnx_op_name: /model.2/m.0/cv1/conv/Conv
# INFO:  input_name.1: /model.2/Split_output_1 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.2: model.2.m.0.cv1.conv.weight shape: [8, 16, 3, 3] dtype: float32
# INFO:  input_name.3: model.2.m.0.cv1.conv.bias shape: [8] dtype: float32
# INFO:  output_name.1: /model.2/m.0/cv1/conv/Conv_output_0 shape: [1, 8, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.strided_slice_1/StridedSlice:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 16, 8) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (8,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_3/Add:0 shape: (1, 160, 160, 8) dtype: <dtype: 'float32'>
#
# INFO: 13 / 321
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.2/m.0/cv1/act/Sigmoid
# INFO:  input_name.1: /model.2/m.0/cv1/conv/Conv_output_0 shape: [1, 8, 160, 160] dtype: float32
# INFO:  output_name.1: /model.2/m.0/cv1/act/Sigmoid_output_0 shape: [1, 8, 160, 160] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_3/Add:0 shape: (1, 160, 160, 8) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_3/Sigmoid:0 shape: (1, 160, 160, 8) dtype: <dtype: 'float32'>
#
# INFO: 14 / 321
# INFO: onnx_op_type: Mul onnx_op_name: /model.2/m.0/cv1/act/Mul
# INFO:  input_name.1: /model.2/m.0/cv1/conv/Conv_output_0 shape: [1, 8, 160, 160] dtype: float32
# INFO:  input_name.2: /model.2/m.0/cv1/act/Sigmoid_output_0 shape: [1, 8, 160, 160] dtype: float32
# INFO:  output_name.1: /model.2/m.0/cv1/act/Mul_output_0 shape: [1, 8, 160, 160] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_3/Add:0 shape: (1, 160, 160, 8) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_3/Sigmoid:0 shape: (1, 160, 160, 8) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_15/Mul:0 shape: (1, 160, 160, 8) dtype: <dtype: 'float32'>
#
# INFO: 15 / 321
# INFO: onnx_op_type: Conv onnx_op_name: /model.2/m.0/cv2/conv/Conv
# INFO:  input_name.1: /model.2/m.0/cv1/act/Mul_output_0 shape: [1, 8, 160, 160] dtype: float32
# INFO:  input_name.2: model.2.m.0.cv2.conv.weight shape: [16, 8, 3, 3] dtype: float32
# INFO:  input_name.3: model.2.m.0.cv2.conv.bias shape: [16] dtype: float32
# INFO:  output_name.1: /model.2/m.0/cv2/conv/Conv_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_15/Mul:0 shape: (1, 160, 160, 8) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 8, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_4/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 16 / 321
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.2/m.0/cv2/act/Sigmoid
# INFO:  input_name.1: /model.2/m.0/cv2/conv/Conv_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.1: /model.2/m.0/cv2/act/Sigmoid_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_4/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_4/Sigmoid:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 17 / 321
# INFO: onnx_op_type: Mul onnx_op_name: /model.2/m.0/cv2/act/Mul
# INFO:  input_name.1: /model.2/m.0/cv2/conv/Conv_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.2: /model.2/m.0/cv2/act/Sigmoid_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.1: /model.2/m.0/cv2/act/Mul_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_4/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_4/Sigmoid:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_19/Mul:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 18 / 321
# INFO: onnx_op_type: Add onnx_op_name: /model.2/m.0/Add
# INFO:  input_name.1: /model.2/Split_output_1 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.2: /model.2/m.0/cv2/act/Mul_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.1: /model.2/m.0/Add_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.strided_slice_1/StridedSlice:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_19/Mul:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_6/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
#
# INFO: 19 / 321
# INFO: onnx_op_type: Concat onnx_op_name: /model.2/Concat
# INFO:  input_name.1: /model.2/Split_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.2: /model.2/Split_output_1 shape: [1, 16, 160, 160] dtype: float32
# INFO:  input_name.3: /model.2/m.0/Add_output_0 shape: [1, 16, 160, 160] dtype: float32
# INFO:  output_name.1: /model.2/Concat_output_0 shape: [1, 48, 160, 160] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.strided_slice/StridedSlice:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.strided_slice_1/StridedSlice:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.input2: name: tf.math.add_6/Add:0 shape: (1, 160, 160, 16) dtype: <dtype: 'float32'>
# INFO:  input.4.axis: val: 3
# INFO:  output.1.output: name: tf.concat/concat:0 shape: (1, 160, 160, 48) dtype: <dtype: 'float32'>
#
# INFO: 20 / 321
# INFO: onnx_op_type: Conv onnx_op_name: /model.2/cv2/conv/Conv
# INFO:  input_name.1: /model.2/Concat_output_0 shape: [1, 48, 160, 160] dtype: float32
# INFO:  input_name.2: model.2.cv2.conv.weight shape: [64, 48, 1, 1] dtype: float32
# INFO:  input_name.3: model.2.cv2.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: /model.2/cv2/conv/Conv_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.concat/concat:0 shape: (1, 160, 160, 48) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 48, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_7/Add:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
#
# INFO: 21 / 321
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.2/cv2/act/Sigmoid
# INFO:  input_name.1: /model.2/cv2/conv/Conv_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  output_name.1: /model.2/cv2/act/Sigmoid_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_7/Add:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_5/Sigmoid:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
#
# INFO: 22 / 321
# INFO: onnx_op_type: Mul onnx_op_name: /model.2/cv2/act/Mul
# INFO:  input_name.1: /model.2/cv2/conv/Conv_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  input_name.2: /model.2/cv2/act/Sigmoid_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  output_name.1: /model.2/cv2/act/Mul_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_7/Add:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_5/Sigmoid:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_25/Mul:0 shape: (1, 160, 160, 64) dtype: <dtype: 'float32'>
#
# INFO: 23 / 321
# INFO: onnx_op_type: Conv onnx_op_name: /model.3/conv/Conv
# INFO:  input_name.1: /model.2/cv2/act/Mul_output_0 shape: [1, 64, 160, 160] dtype: float32
# INFO:  input_name.2: model.3.conv.weight shape: [64, 64, 3, 3] dtype: float32
# INFO:  input_name.3: model.3.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: /model.3/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.pad_2/Pad:0 shape: (1, 162, 162, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_8/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 24 / 321
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.3/act/Sigmoid
# INFO:  input_name.1: /model.3/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  output_name.1: /model.3/act/Sigmoid_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_8/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_6/Sigmoid:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 25 / 321
# INFO: onnx_op_type: Mul onnx_op_name: /model.3/act/Mul
# INFO:  input_name.1: /model.3/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  input_name.2: /model.3/act/Sigmoid_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  output_name.1: /model.3/act/Mul_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_8/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_6/Sigmoid:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_29/Mul:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 26 / 321
# INFO: onnx_op_type: Conv onnx_op_name: /model.4/cv1/conv/Conv
# INFO:  input_name.1: /model.3/act/Mul_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  input_name.2: model.4.cv1.conv.weight shape: [64, 64, 1, 1] dtype: float32
# INFO:  input_name.3: model.4.cv1.conv.bias shape: [64] dtype: float32
# INFO:  output_name.1: /model.4/cv1/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_29/Mul:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 64, 64) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (64,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_9/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 27 / 321
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.4/cv1/act/Sigmoid
# INFO:  input_name.1: /model.4/cv1/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  output_name.1: /model.4/cv1/act/Sigmoid_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_9/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_7/Sigmoid:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 28 / 321
# INFO: onnx_op_type: Mul onnx_op_name: /model.4/cv1/act/Mul
# INFO:  input_name.1: /model.4/cv1/conv/Conv_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  input_name.2: /model.4/cv1/act/Sigmoid_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  output_name.1: /model.4/cv1/act/Mul_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_9/Add:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_7/Sigmoid:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_33/Mul:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
#
# INFO: 29 / 321
# INFO: onnx_op_type: Split onnx_op_name: /model.4/Split
# INFO:  input_name.1: /model.4/cv1/act/Mul_output_0 shape: [1, 64, 80, 80] dtype: float32
# INFO:  input_name.2: onnx::Split_205 shape: [2] dtype: int64
# INFO:  output_name.1: /model.4/Split_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.2: /model.4/Split_output_1 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: split
# INFO:  input.1.value: name: tf.math.multiply_33/Mul:0 shape: (1, 80, 80, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.num_or_size_splits: shape: (2,) dtype: int64
# INFO:  input.3.axis: val: 3
# INFO:  input.4.num:
# INFO:  output.1.output0: name: tf.strided_slice_2/StridedSlice:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.2.output1: name: tf.strided_slice_3/StridedSlice:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 30 / 321
# INFO: onnx_op_type: Conv onnx_op_name: /model.4/m.0/cv1/conv/Conv
# INFO:  input_name.1: /model.4/Split_output_1 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: model.4.m.0.cv1.conv.weight shape: [16, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.4.m.0.cv1.conv.bias shape: [16] dtype: float32
# INFO:  output_name.1: /model.4/m.0/cv1/conv/Conv_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.strided_slice_3/StridedSlice:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 16) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (16,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_10/Add:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
#
# INFO: 31 / 321
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.4/m.0/cv1/act/Sigmoid
# INFO:  input_name.1: /model.4/m.0/cv1/conv/Conv_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO:  output_name.1: /model.4/m.0/cv1/act/Sigmoid_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_10/Add:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_8/Sigmoid:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
#
# INFO: 32 / 321
# INFO: onnx_op_type: Mul onnx_op_name: /model.4/m.0/cv1/act/Mul
# INFO:  input_name.1: /model.4/m.0/cv1/conv/Conv_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO:  input_name.2: /model.4/m.0/cv1/act/Sigmoid_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO:  output_name.1: /model.4/m.0/cv1/act/Mul_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_10/Add:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_8/Sigmoid:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_37/Mul:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
#
# INFO: 33 / 321
# INFO: onnx_op_type: Conv onnx_op_name: /model.4/m.0/cv2/conv/Conv
# INFO:  input_name.1: /model.4/m.0/cv1/act/Mul_output_0 shape: [1, 16, 80, 80] dtype: float32
# INFO:  input_name.2: model.4.m.0.cv2.conv.weight shape: [32, 16, 3, 3] dtype: float32
# INFO:  input_name.3: model.4.m.0.cv2.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: /model.4/m.0/cv2/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_37/Mul:0 shape: (1, 80, 80, 16) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 16, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_11/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 34 / 321
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.4/m.0/cv2/act/Sigmoid
# INFO:  input_name.1: /model.4/m.0/cv2/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: /model.4/m.0/cv2/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_11/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_9/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 35 / 321
# INFO: onnx_op_type: Mul onnx_op_name: /model.4/m.0/cv2/act/Mul
# INFO:  input_name.1: /model.4/m.0/cv2/conv/Conv_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: /model.4/m.0/cv2/act/Sigmoid_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: /model.4/m.0/cv2/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_11/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_9/Sigmoid:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_41/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 36 / 321
# INFO: onnx_op_type: Add onnx_op_name: /model.4/m.0/Add
# INFO:  input_name.1: /model.4/Split_output_1 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: /model.4/m.0/cv2/act/Mul_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: /model.4/m.0/Add_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.strided_slice_3/StridedSlice:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_41/Mul:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_13/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
#
# INFO: 37 / 321
# INFO: onnx_op_type: Concat onnx_op_name: /model.4/Concat
# INFO:  input_name.1: /model.4/Split_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.2: /model.4/Split_output_1 shape: [1, 32, 80, 80] dtype: float32
# INFO:  input_name.3: /model.4/m.0/Add_output_0 shape: [1, 32, 80, 80] dtype: float32
# INFO:  output_name.1: /model.4/Concat_output_0 shape: [1, 96, 80, 80] dtype: float32
# INFO: tf_op_type: concat
# INFO:  input.1.input0: name: tf.strided_slice_2/StridedSlice:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.input1: name: tf.strided_slice_3/StridedSlice:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.input2: name: tf.math.add_13/Add:0 shape: (1, 80, 80, 32) dtype: <dtype: 'float32'>
# INFO:  input.4.axis: val: 3
# INFO:  output.1.output: name: tf.concat_1/concat:0 shape: (1, 80, 80, 96) dtype: <dtype: 'float32'>
#
# INFO: 38 / 321
# INFO: onnx_op_type: Conv onnx_op_name: /model.4/cv2/conv/Conv
# INFO:  input_name.1: /model.4/Concat_output_0 shape: [1, 96, 80, 80] dtype: float32
# INFO:  input_name.2: model.4.cv2.conv.weight shape: [128, 96, 1, 1] dtype: float32
# INFO:  input_name.3: model.4.cv2.conv.bias shape: [128] dtype: float32
# INFO:  output_name.1: /model.4/cv2/conv/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.concat_1/concat:0 shape: (1, 80, 80, 96) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 96, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_14/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 39 / 321
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.4/cv2/act/Sigmoid
# INFO:  input_name.1: /model.4/cv2/conv/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  output_name.1: /model.4/cv2/act/Sigmoid_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_14/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_10/Sigmoid:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 40 / 321
# INFO: onnx_op_type: Mul onnx_op_name: /model.4/cv2/act/Mul
# INFO:  input_name.1: /model.4/cv2/conv/Conv_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  input_name.2: /model.4/cv2/act/Sigmoid_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  output_name.1: /model.4/cv2/act/Mul_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_14/Add:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_10/Sigmoid:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_47/Mul:0 shape: (1, 80, 80, 128) dtype: <dtype: 'float32'>
#
# INFO: 41 / 321
# INFO: onnx_op_type: Conv onnx_op_name: /model.5/conv/Conv
# INFO:  input_name.1: /model.4/cv2/act/Mul_output_0 shape: [1, 128, 80, 80] dtype: float32
# INFO:  input_name.2: model.5.conv.weight shape: [128, 128, 3, 3] dtype: float32
# INFO:  input_name.3: model.5.conv.bias shape: [128] dtype: float32
# INFO:  output_name.1: /model.5/conv/Conv_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.compat.v1.pad_3/Pad:0 shape: (1, 82, 82, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 128, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [2, 2]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: VALID
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_15/Add:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
#
# INFO: 42 / 321
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.5/act/Sigmoid
# INFO:  input_name.1: /model.5/conv/Conv_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  output_name.1: /model.5/act/Sigmoid_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_15/Add:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_11/Sigmoid:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
#
# INFO: 43 / 321
# INFO: onnx_op_type: Mul onnx_op_name: /model.5/act/Mul
# INFO:  input_name.1: /model.5/conv/Conv_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  input_name.2: /model.5/act/Sigmoid_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  output_name.1: /model.5/act/Mul_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_15/Add:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_11/Sigmoid:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_51/Mul:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
#
# INFO: 44 / 321
# INFO: onnx_op_type: Conv onnx_op_name: /model.6/cv1/conv/Conv
# INFO:  input_name.1: /model.5/act/Mul_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  input_name.2: model.6.cv1.conv.weight shape: [128, 128, 1, 1] dtype: float32
# INFO:  input_name.3: model.6.cv1.conv.bias shape: [128] dtype: float32
# INFO:  output_name.1: /model.6/cv1/conv/Conv_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_51/Mul:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 128, 128) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (128,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_16/Add:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
#
# INFO: 45 / 321
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.6/cv1/act/Sigmoid
# INFO:  input_name.1: /model.6/cv1/conv/Conv_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  output_name.1: /model.6/cv1/act/Sigmoid_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_16/Add:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_12/Sigmoid:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
#
# INFO: 46 / 321
# INFO: onnx_op_type: Mul onnx_op_name: /model.6/cv1/act/Mul
# INFO:  input_name.1: /model.6/cv1/conv/Conv_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  input_name.2: /model.6/cv1/act/Sigmoid_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  output_name.1: /model.6/cv1/act/Mul_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_16/Add:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_12/Sigmoid:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_55/Mul:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
#
# INFO: 47 / 321
# INFO: onnx_op_type: Split onnx_op_name: /model.6/Split
# INFO:  input_name.1: /model.6/cv1/act/Mul_output_0 shape: [1, 128, 40, 40] dtype: float32
# INFO:  input_name.2: onnx::Split_225 shape: [2] dtype: int64
# INFO:  output_name.1: /model.6/Split_output_0 shape: [1, 64, 40, 40] dtype: float32
# INFO:  output_name.2: /model.6/Split_output_1 shape: [1, 64, 40, 40] dtype: float32
# INFO: tf_op_type: split
# INFO:  input.1.value: name: tf.math.multiply_55/Mul:0 shape: (1, 40, 40, 128) dtype: <dtype: 'float32'>
# INFO:  input.2.num_or_size_splits: shape: (2,) dtype: int64
# INFO:  input.3.axis: val: 3
# INFO:  input.4.num:
# INFO:  output.1.output0: name: tf.strided_slice_4/StridedSlice:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  output.2.output1: name: tf.strided_slice_5/StridedSlice:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
#
# INFO: 48 / 321
# INFO: onnx_op_type: Conv onnx_op_name: /model.6/m.0/cv1/conv/Conv
# INFO:  input_name.1: /model.6/Split_output_1 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: model.6.m.0.cv1.conv.weight shape: [32, 64, 1, 1] dtype: float32
# INFO:  input_name.3: model.6.m.0.cv1.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: /model.6/m.0/cv1/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.strided_slice_5/StridedSlice:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 64, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_17/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 49 / 321
# INFO: onnx_op_type: Conv onnx_op_name: /model.6/m.0/cv2/conv/Conv
# INFO:  input_name.1: /model.6/Split_output_1 shape: [1, 64, 40, 40] dtype: float32
# INFO:  input_name.2: model.6.m.0.cv2.conv.weight shape: [32, 64, 1, 1] dtype: float32
# INFO:  input_name.3: model.6.m.0.cv2.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: /model.6/m.0/cv2/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.strided_slice_5/StridedSlice:0 shape: (1, 40, 40, 64) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (1, 1, 64, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_18/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 50 / 321
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.6/m.0/cv1/act/Sigmoid
# INFO:  input_name.1: /model.6/m.0/cv1/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: /model.6/m.0/cv1/act/Sigmoid_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_17/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_13/Sigmoid:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 51 / 321
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.6/m.0/cv2/act/Sigmoid
# INFO:  input_name.1: /model.6/m.0/cv2/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: /model.6/m.0/cv2/act/Sigmoid_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_18/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_14/Sigmoid:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 52 / 321
# INFO: onnx_op_type: Mul onnx_op_name: /model.6/m.0/cv1/act/Mul
# INFO:  input_name.1: /model.6/m.0/cv1/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: /model.6/m.0/cv1/act/Sigmoid_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: /model.6/m.0/cv1/act/Mul_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_17/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_13/Sigmoid:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_59/Mul:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 53 / 321
# INFO: onnx_op_type: Mul onnx_op_name: /model.6/m.0/cv2/act/Mul
# INFO:  input_name.1: /model.6/m.0/cv2/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: /model.6/m.0/cv2/act/Sigmoid_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: /model.6/m.0/cv2/act/Mul_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_18/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_14/Sigmoid:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_63/Mul:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 54 / 321
# INFO: onnx_op_type: Conv onnx_op_name: /model.6/m.0/m/m.0/cv1/conv/Conv
# INFO:  input_name.1: /model.6/m.0/cv1/act/Mul_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: model.6.m.0.m.0.cv1.conv.weight shape: [32, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.6.m.0.m.0.cv1.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m/m.0/cv1/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_59/Mul:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_19/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 55 / 321
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.6/m.0/m/m.0/cv1/act/Sigmoid
# INFO:  input_name.1: /model.6/m.0/m/m.0/cv1/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m/m.0/cv1/act/Sigmoid_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_19/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_15/Sigmoid:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 56 / 321
# INFO: onnx_op_type: Mul onnx_op_name: /model.6/m.0/m/m.0/cv1/act/Mul
# INFO:  input_name.1: /model.6/m.0/m/m.0/cv1/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m/m.0/cv1/act/Sigmoid_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m/m.0/cv1/act/Mul_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_19/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_15/Sigmoid:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_67/Mul:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 57 / 321
# INFO: onnx_op_type: Conv onnx_op_name: /model.6/m.0/m/m.0/cv2/conv/Conv
# INFO:  input_name.1: /model.6/m.0/m/m.0/cv1/act/Mul_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: model.6.m.0.m.0.cv2.conv.weight shape: [32, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.6.m.0.m.0.cv2.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m/m.0/cv2/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_67/Mul:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_20/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 58 / 321
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.6/m.0/m/m.0/cv2/act/Sigmoid
# INFO:  input_name.1: /model.6/m.0/m/m.0/cv2/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m/m.0/cv2/act/Sigmoid_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_20/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_16/Sigmoid:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 59 / 321
# INFO: onnx_op_type: Mul onnx_op_name: /model.6/m.0/m/m.0/cv2/act/Mul
# INFO:  input_name.1: /model.6/m.0/m/m.0/cv2/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m/m.0/cv2/act/Sigmoid_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m/m.0/cv2/act/Mul_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_20/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_16/Sigmoid:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_71/Mul:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 60 / 321
# INFO: onnx_op_type: Add onnx_op_name: /model.6/m.0/m/m.0/Add
# INFO:  input_name.1: /model.6/m.0/cv1/act/Mul_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m/m.0/cv2/act/Mul_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m/m.0/Add_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: add
# INFO:  input.1.x: name: tf.math.multiply_59/Mul:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.multiply_71/Mul:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.add_22/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 61 / 321
# INFO: onnx_op_type: Conv onnx_op_name: /model.6/m.0/m/m.1/cv1/conv/Conv
# INFO:  input_name.1: /model.6/m.0/m/m.0/Add_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: model.6.m.0.m.1.cv1.conv.weight shape: [32, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.6.m.0.m.1.cv1.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m/m.1/cv1/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.add_22/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 32) dtype: <dtype: 'float32'>
# INFO:  input.3.bias: shape: (32,) dtype: <dtype: 'float32'>
# INFO:  input.4.strides: val: [1, 1]
# INFO:  input.5.dilations: val: [1, 1]
# INFO:  input.6.padding: val: SAME
# INFO:  input.7.group: val: 1
# INFO:  output.1.output: name: tf.math.add_23/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 62 / 321
# INFO: onnx_op_type: Sigmoid onnx_op_name: /model.6/m.0/m/m.1/cv1/act/Sigmoid
# INFO:  input_name.1: /model.6/m.0/m/m.1/cv1/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m/m.1/cv1/act/Sigmoid_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: sigmoid
# INFO:  input.1.x: name: tf.math.add_23/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.sigmoid_17/Sigmoid:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 63 / 321
# INFO: onnx_op_type: Mul onnx_op_name: /model.6/m.0/m/m.1/cv1/act/Mul
# INFO:  input_name.1: /model.6/m.0/m/m.1/cv1/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: /model.6/m.0/m/m.1/cv1/act/Sigmoid_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m/m.1/cv1/act/Mul_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: multiply
# INFO:  input.1.x: name: tf.math.add_23/Add:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.y: name: tf.math.sigmoid_17/Sigmoid:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  output.1.output: name: tf.math.multiply_77/Mul:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
#
# INFO: 64 / 321
# INFO: onnx_op_type: Conv onnx_op_name: /model.6/m.0/m/m.1/cv2/conv/Conv
# INFO:  input_name.1: /model.6/m.0/m/m.1/cv1/act/Mul_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO:  input_name.2: model.6.m.0.m.1.cv2.conv.weight shape: [32, 32, 3, 3] dtype: float32
# INFO:  input_name.3: model.6.m.0.m.1.cv2.conv.bias shape: [32] dtype: float32
# INFO:  output_name.1: /model.6/m.0/m/m.1/cv2/conv/Conv_output_0 shape: [1, 32, 40, 40] dtype: float32
# INFO: tf_op_type: convolution_v2
# INFO:  input.1.input: name: tf.math.multiply_77/Mul:0 shape: (1, 40, 40, 32) dtype: <dtype: 'float32'>
# INFO:  input.2.weights: shape: (3, 3, 32, 32) dtype: <dtype: 'float32'>
# ...
# INFO:  input.2.input1: name: tf.math.sigmoid_77/Sigmoid:0 shape: (1, 1, 8400) dtype: <dtype: 'float32'>
# INFO:  input.3.axis: val: 1
# INFO:  output.1.output: name: tf.concat_25/concat:0 shape: (1, 5, 8400) dtype: <dtype: 'float32'>
#
# saved_model output started ==========================================================
# Saved artifact at 'i8'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 640, 640, 3), dtype=tf.float32, name='images')
# Output Type:
#   TensorSpec(shape=(1, 5, 8400), dtype=tf.float32, name=None)
# Captures:
#   132273007436112: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132273007435920: TensorSpec(shape=(3, 3, 3, 16), dtype=tf.float32, name=None)
#   132273007437072: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   132273007441872: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132273007441680: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   132273007441296: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132273007442256: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   132273007442064: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   132273007442448: TensorSpec(shape=(3, 3, 16, 8), dtype=tf.float32, name=None)
#   132273007439184: TensorSpec(shape=(8,), dtype=tf.float32, name=None)
#   132273007443024: TensorSpec(shape=(3, 3, 8, 16), dtype=tf.float32, name=None)
#   132273007442832: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   132273007442640: TensorSpec(shape=(1, 1, 48, 64), dtype=tf.float32, name=None)
#   132273007443216: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132273007443792: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   132273007443408: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   132272650486032: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132272650486416: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   132272650486224: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   132272